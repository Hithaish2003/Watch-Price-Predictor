# %% [markdown]
# # Ingestion

# %%
import pandas as pd

# %%
df=pd.read_csv('Luxury watch.csv')

# %%
df
# Out:
#                    Brand    Case Material   Strap Material Movement Type  \
# 0                  Rolex  Stainless Steel  Stainless Steel     Automatic
# 1                  Omega         Titanium           Rubber     Automatic
# 2              Tag Heuer  Stainless Steel          Leather     Automatic
# 3              Breitling  Stainless Steel  Stainless Steel     Automatic
# 4                Cartier  Stainless Steel          Leather        Quartz
# ..                   ...              ...              ...           ...
# 501              Breguet    18k Rose Gold          Leather     Automatic
# 502            Blancpain  Stainless Steel           Fabric     Automatic
# 503             Longines  Stainless Steel          Leather     Automatic
# 504  Vacheron Constantin  Stainless Steel  Stainless Steel     Automatic
# 505  Frederique Constant  Stainless Steel          Leather     Automatic
#
#     Water Resistance  Case Diameter (mm)  Case Thickness (mm)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                506 non-null    object
#  1   Case Material        506 non-null    object
#  2   Strap Material       506 non-null    object
#  3   Movement Type        506 non-null    object
#  4   Water Resistance     506 non-null    object
#  5   Case Diameter (mm)   506 non-null    float64
#  6   Case Thickness (mm)  506 non-null    float64
#  7   Band Width (mm)      506 non-null    float64
#  8   Dial Color           506 non-null    object
#  9   Crystal Material     506 non-null    object
#  10  Power Reserve        492 non-null    object
#  11  Price (USD)          505 non-null    object
# dtypes: float64(3), object(9)
# memory usage: 47.6+ KB

# %% [markdown]
# ## Treating the Missing Values

# %%
df.isna().sum()
# Out:
# Brand                   0
# Case Material           0
# Strap Material          0
# Movement Type           0
# Water Resistance        0
# Case Diameter (mm)      0
# Case Thickness (mm)     0
# Band Width (mm)         0
# Dial Color              0
# Crystal Material        0
# Power Reserve          14
# Price (USD)             1
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isna().sum()
# Out:
# Brand                  0
# Case Material          0
# Strap Material         0
# Movement Type          0
# Water Resistance       0
# Case Diameter (mm)     0
# Case Thickness (mm)    0
# Band Width (mm)        0
# Dial Color             0
# Crystal Material       0
# Power Reserve          0
# Price (USD)            0
# dtype: int64

# %% [markdown]
# ## Checking for Duplicates

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 5      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# Length: 491, dtype: bool

# %%
df.head()
# Out:
#               Brand    Case Material   Strap Material Movement Type  \
# 0             Rolex  Stainless Steel  Stainless Steel     Automatic
# 1             Omega         Titanium           Rubber     Automatic
# 2         Tag Heuer  Stainless Steel          Leather     Automatic
# 3         Breitling  Stainless Steel  Stainless Steel     Automatic
# 5  Jaeger-LeCoultre  Stainless Steel          Leather        Manual
#
#   Water Resistance  Case Diameter (mm)  Case Thickness (mm)  Band Width (mm)  \
# 0       300 meters                40.0                13.00             20.0
# 1       600 meters                43.5                14.47             21.0
# 2       100 meters                41.0                13.00             20.0
# 3        30 meters                43.0                14.25             22.0
# 5        30 meters                42.9                 9.20             20.0
#
#   Dial Color Crystal Material Power Reserve Price (USD)
# ...

# %% [markdown]
# ### TypeCasting Feature

# %%
df['Price (USD)']=df['Price (USD)'].str.replace(',','')

df['Price (USD)'] = df['Price (USD)'].astype(float)

df['Water Resistance']=df['Water Resistance'].str.replace('meters','')

df['Water Resistance'] = df['Water Resistance'].astype(float)

df.head()

df['Power Reserve']=df['Power Reserve'].str.replace('hours','')

df['Power Reserve']=df['Power Reserve'].str.replace('days','')

df['Power Reserve'] = df['Power Reserve'].astype(float)

# %%
df.head()
# Out:
#               Brand    Case Material   Strap Material Movement Type  \
# 0             Rolex  Stainless Steel  Stainless Steel     Automatic
# 1             Omega         Titanium           Rubber     Automatic
# 2         Tag Heuer  Stainless Steel          Leather     Automatic
# 3         Breitling  Stainless Steel  Stainless Steel     Automatic
# 5  Jaeger-LeCoultre  Stainless Steel          Leather        Manual
#
#    Water Resistance  Case Diameter (mm)  Case Thickness (mm)  Band Width (mm)  \
# 0             300.0                40.0                13.00             20.0
# 1             600.0                43.5                14.47             21.0
# 2             100.0                41.0                13.00             20.0
# 3              30.0                43.0                14.25             22.0
# 5              30.0                42.9                 9.20             20.0
#
#   Dial Color Crystal Material  Power Reserve  Price (USD)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 491 entries, 0 to 505
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                491 non-null    object
#  1   Case Material        491 non-null    object
#  2   Strap Material       491 non-null    object
#  3   Movement Type        491 non-null    object
#  4   Water Resistance     491 non-null    float64
#  5   Case Diameter (mm)   491 non-null    float64
#  6   Case Thickness (mm)  491 non-null    float64
#  7   Band Width (mm)      491 non-null    float64
#  8   Dial Color           491 non-null    object
#  9   Crystal Material     491 non-null    object
#  10  Power Reserve        491 non-null    float64
#  11  Price (USD)          491 non-null    float64
# dtypes: float64(6), object(6)
# memory usage: 49.9+ KB

# %% [markdown]
# ## Treating Outliers

# %%
import seaborn as sns
sns.boxplot(x=df['Water Resistance'],data=df)
# Out:
# <Axes: xlabel='Water Resistance'>

# %%
sns.boxplot(x=df['Case Diameter (mm)'],data=df)
# Out:
# <Axes: xlabel='Case Diameter (mm)'>

# %%
sns.boxplot(x=df['Case Thickness (mm)'],data=df)
# Out:
# <Axes: xlabel='Case Thickness (mm)'>

# %%
sns.boxplot(x=df['Band Width (mm)'],data=df)
# Out:
# <Axes: xlabel='Band Width (mm)'>

# %%
sns.boxplot(x=df['Power Reserve'],data=df)
# Out:
# <Axes: xlabel='Power Reserve'>

# %%
sns.boxplot(x=df['Price (USD)'],data=df)
# Out:
# <Axes: xlabel='Price (USD)'>

# %% [markdown]
# ## Removing Outliers

# %%
col=['Case Diameter (mm)','Band Width (mm)','Water Resistance','Price (USD)','Power Reserve']
Q3=df[col].quantile(0.75)
Q1=df[col].quantile(0.25)
IQR=Q3-Q1
lb=Q1-1.5*IQR
ub=Q3+1.5*IQR
outlier=df[((df[col]<=lb) | (df[col]>=ub)).any(axis=1)]
df=df.drop(outlier.index)

# %%
sns.boxplot(x=df['Water Resistance'],data=df)
# Out:
# <Axes: xlabel='Water Resistance'>

# %%
sns.boxplot(x=df['Price (USD)'],data=df)
# Out:
# <Axes: xlabel='Price (USD)'>

# %%
sns.boxplot(x=df['Power Reserve'],data=df)
# Out:
# <Axes: xlabel='Power Reserve'>

# %%
sns.boxplot(x=df['Case Diameter (mm)'],data=df)
# Out:
# <Axes: xlabel='Case Diameter (mm)'>

# %%
sns.boxplot(x=df['Band Width (mm)'],data=df)
# Out:
# <Axes: xlabel='Band Width (mm)'>

# %%
df.head()
# Out:
#               Brand    Case Material   Strap Material Movement Type  \
# 2         Tag Heuer  Stainless Steel          Leather     Automatic
# 3         Breitling  Stainless Steel  Stainless Steel     Automatic
# 5  Jaeger-LeCoultre  Stainless Steel          Leather        Manual
# 6             Seiko  Stainless Steel           Rubber     Automatic
# 8            Tissot  Stainless Steel          Leather     Automatic
#
#    Water Resistance  Case Diameter (mm)  Case Thickness (mm)  Band Width (mm)  \
# 2             100.0                41.0                13.00             20.0
# 3              30.0                43.0                14.25             22.0
# 5              30.0                42.9                 9.20             20.0
# 6             200.0                44.3                12.90             20.0
# 8              30.0                39.3                 9.75             19.0
#
#   Dial Color Crystal Material  Power Reserve  Price (USD)
# ...

# %% [markdown]
# ## Feature Scaling

# %% [markdown]
# from sklearn.preprocessing import MinMaxScaler
# mm=MinMaxScaler()
# df['Price (USD)']=mm.fit_transform(df[['Price (USD)']])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 356 entries, 2 to 505
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                356 non-null    object
#  1   Case Material        356 non-null    object
#  2   Strap Material       356 non-null    object
#  3   Movement Type        356 non-null    object
#  4   Water Resistance     356 non-null    float64
#  5   Case Diameter (mm)   356 non-null    float64
#  6   Case Thickness (mm)  356 non-null    float64
#  7   Band Width (mm)      356 non-null    float64
#  8   Dial Color           356 non-null    object
#  9   Crystal Material     356 non-null    object
#  10  Power Reserve        356 non-null    float64
#  11  Price (USD)          356 non-null    float64
# dtypes: float64(6), object(6)
# memory usage: 36.2+ KB

# %% [markdown]
# ## Label Encoding

# %%
lblnc=['Brand','Case Material','Strap Material','Movement Type','Dial Color','Crystal Material']
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
for i in lblnc:
    df[i]=lb.fit_transform(df[i])

# %%
import pickle as pk
with open('lable.pkl','wb') as f:
    pk.dump(lb,f)

# %%
df.head()
# Out:
#    Brand  Case Material  Strap Material  Movement Type  Water Resistance  \
# 2     27             11               3              0             100.0
# 3      5             11               7              0              30.0
# 5     15             11               3              1              30.0
# 6     25             11               5              0             200.0
# 8     28             11               3              0              30.0
#
#    Case Diameter (mm)  Case Thickness (mm)  Band Width (mm)  Dial Color  \
# 2                41.0                13.00             20.0           5
# 3                43.0                14.25             22.0           0
# 5                42.9                 9.20             20.0           0
# 6                44.3                12.90             20.0           0
# 8                39.3                 9.75             19.0           5
#
#    Crystal Material  Power Reserve  Price (USD)
# ...

# %%
df.corr()
# Out:
#                         Brand  Case Material  Strap Material  Movement Type  \
# Brand                1.000000       0.174001       -0.137369      -0.042394
# Case Material        0.174001       1.000000        0.193194      -0.313696
# Strap Material      -0.137369       0.193194        1.000000      -0.096417
# Movement Type       -0.042394      -0.313696       -0.096417       1.000000
# Water Resistance     0.442256       0.223247        0.207741      -0.258024
# Case Diameter (mm)   0.034366       0.263931        0.219275      -0.038752
# Case Thickness (mm)  0.235804       0.331113        0.074767      -0.221509
# Band Width (mm)      0.108242       0.125027       -0.020534      -0.152074
# Dial Color           0.023514      -0.305489       -0.380977       0.082762
# Crystal Material    -0.085812      -0.052696       -0.213242      -0.293821
# Power Reserve        0.006858       0.084260        0.086072      -0.094374
# ...

# %% [markdown]
# from sklearn.decomposition import PCA
# pca=PCA(n_components=8)
# x=df.iloc[:,0:11]
# transformed=pca.fit_transform(x)
# transformed

# %% [markdown]
# ## MultiLinear Regression

# %%
x=df.iloc[:,0:11]
y=df['Price (USD)']

# %%
from sklearn.feature_selection import SelectKBest,chi2
sh=SelectKBest(chi2,k=3)
sh.fit_transform(x,y)
# Out:
# array([[ 27., 100.,  42.],
#        [  5.,  30.,  70.],
#        [ 15.,  30.,  45.],
#        ...,
#        [ 17.,  30.,  64.],
#        [ 31., 150.,  40.],
#        [  9.,  50.,  38.]])

# %%
x=df[['Brand','Water Resistance','Power Reserve']]

# %%
from sklearn.model_selection import train_test_split
xtrainR,xtestR,ytrainR,ytestR=train_test_split(x,y,test_size=0.3,shuffle=True,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
slr=LinearRegression()
slr.fit(xtrainR,ytrainR)
# Out:
# LinearRegression()

# %%
ypredR=slr.predict(xtestR)

# %%
from sklearn.metrics import r2_score
r2_score(ytestR,ypredR)
# Out:
# -0.08347471043726151

# %%
from sklearn.linear_model import Lasso
las=Lasso()
dtr_lr=las.fit(xtrainR,ytrainR)

print(dtr_lr)

print(dtr_lr.score(xtrainR,ytrainR))
print(dtr_lr.score(xtestR,ytestR))

from sklearn.linear_model import Ridge
rdg=Ridge()
dtr_rdg=rdg.fit(xtrainR,ytrainR)

print(dtr_rdg)

print(dtr_rdg.score(xtrainR,ytrainR))
print(dtr_rdg.score(xtestR,ytestR))

from sklearn.linear_model import ElasticNet
elc=ElasticNet()
dtr_elc=elc.fit(xtrainR,ytrainR)

print(dtr_elc)

print(dtr_elc.score(xtrainR,ytrainR))
print(dtr_elc.score(xtestR,ytestR))
# Out:
# Lasso()
# 0.1579650274939166
# -0.08346577456699178
# Ridge()
# 0.1579650275526232
# -0.08346739000509817
# ElasticNet()
# 0.15796141393680307
# -0.0825682710957274

# %% [markdown]
# ## Polynomial Regression Model

# %%
from sklearn.preprocessing import PolynomialFeatures
ply=PolynomialFeatures(degree=3)
xpoly=ply.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,shuffle=True,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
plr=LinearRegression()
plr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ytrain_pred=plr.predict(xtrain)

# %%
r2_score(ytrain,ytrain_pred)
# Out:
# 0.15796502778676746

# %%
ytest_pred=plr.predict(xtest)

# %%
r2_score(ytest,ytest_pred)
# Out:
# -0.08347471043726151

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,shuffle=True,random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor(max_depth= 10,max_features='sqrt', min_samples_leaf= 2, min_samples_split= 5)
dtr.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor(max_depth=10, max_features='sqrt', min_samples_leaf=2,
#                       min_samples_split=5)

# %%
dtr.score(xtrain,ytrain)
# Out:
# 0.8536818365844604

# %%
dtr.score(xtest,ytest)
# Out:
# 0.44130384116524146

# %%
dtr_ypred=dtr.predict(xtest)
r2_score(ytest,dtr_ypred)
# Out:
# 0.44130384116524146

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {
    'max_depth': [3, 5, 7, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}
dtr = DecisionTreeRegressor(random_state=42)
grid_search = GridSearchCV(
    estimator=dtr,
    param_grid=param_grid,
    cv=5,
    n_jobs=-1,
    scoring='r2',
    verbose=2
)
grid_search.fit(xtrain, ytrain)
print("Best Parameters:", grid_search.best_params_)
print("Best R² Score:", grid_search.best_score_)
best_model = grid_search.best_estimator_
test_score = best_model.score(xtest, ytest)
print("Test Score:", test_score)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5}
# Best R² Score: 0.7575840619031591
# Test Score: 0.7444660892634836
# C:\Users\kahit\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 180 fits failed out of a total of 540.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 141 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\kahit\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
import pickle as pk
with open('WatchPrice.pkl','wb')as f:
    pk.dump(grid_search.best_estimator_,f)

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,shuffle=True,random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(max_depth= None, max_features= 'sqrt', min_samples_leaf= 1, min_samples_split= 5, n_estimators= 50)
rfr.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor(max_features='sqrt', min_samples_split=5, n_estimators=50)

# %%
print(rfr.score(xtrain,ytrain))
print(rfr.score(xtest,ytest))
# Out:
# 0.9108074006321805
# 0.723824670979133

# %%
rfr_ypred=rfr.predict(xtest)
r2_score(ytest,rfr_ypred)
# Out:
# 0.723824670979133

# %% [markdown]
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.model_selection import GridSearchCV
#
# param_grid = {
#     'n_estimators': [50, 100, 150],
#     'max_depth': [None, 10, 20],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4],
#     'max_features': ['sqrt', 'log2']
# }
#
# rfr = RandomForestRegressor(random_state=42)
#
# grid_search = GridSearchCV(
#     estimator=rfr,
#     param_grid=param_grid,
#     cv=5,
#     n_jobs=-1,
#     scoring='r2',
#     verbose=2
# )
#
# grid_search.fit(xtrain, ytrain)
#
# # Results
# print("Best Parameters:", grid_search.best_params_)
# print("Best R² Score:", grid_search.best_score_)
# print("Test Set Score:", grid_search.best_estimator_.score(xtest, ytest))

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,shuffle=True,random_state=1)

# %%
from sklearn.svm import SVR
svr=SVR(kernel='poly')
svr.fit(xtrain, ytrain)
# Out:
# SVR(kernel='poly')

# %%
print(svr.score(xtrain,ytrain))
print(svr.score(xtest,ytest))
# Out:
# -0.15272592136769192
# -0.09497822126250455

# %%
svr_ypred=svr.predict(xtest)

# %%
r2_score(ytest,svr_ypred)
# Out:
# -0.09497822126250455

# %% [markdown]
# # XGBoost

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,shuffle=True,random_state=1)

# %%
from xgboost import XGBRegressor
xgb=XGBRegressor()
xgb.fit(xtrain, ytrain)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ### Training and Testing Accuracy

# %%
print(xgb.score(xtrain,ytrain))
print(xgb.score(xtest,ytest))
# Out:
# 0.9329663892304991
# 0.7586773697178342

# %%
xgb_ypred=xgb.predict(xtest)

# %% [markdown]
# ### Model Accuracy

# %%
r2_score(ytest,xgb_ypred)
# Out:
# 0.7586773697178342

# %%
df['Brand'].unique()
# Out:
# array([27,  5, 15, 25, 28, 12, 17, 20,  3,  4,  2, 31, 19, 21, 29, 24, 14,
#        18, 32, 23, 30, 16,  8, 10, 11, 13, 22,  7,  0,  9,  6, 26,  1])

# %% [markdown]
# # Testing For a new Data

# %%
sdf=pd.read_csv('Luxury watch.csv')

# %%
lbls=sdf['Brand']

# %%
lbls.unique()
# Out:
# array(['Rolex', 'Omega', 'Tag Heuer', 'Breitling', 'Cartier',
#        'Jaeger-LeCoultre', 'Seiko', 'Citizen', 'Tissot', 'Hamilton',
#        'Longines', 'Oris', 'Bell & Ross', 'Breguet', 'Audemars Piguet',
#        'Vacheron Constantin', 'Panerai', 'Tudor', 'IWC', 'Montblanc',
#        'Blancpain', 'Zenith', 'Piaget', 'Ulysse Nardin', 'Jaquet Droz',
#        'Bulgari', 'Chopard', 'Girard-Perregaux', 'Glashütte Original',
#        'Hublot', 'Patek Philippe', 'Bulova', 'Sinn', 'A. Lange & Sohne',
#        'Rado', 'Frederique Constant', 'TAG Heuer', 'Baume & Mercier',
#        'A. Lange & Söhne'], dtype=object)

# %%
for i in lbls.unique():
    print(i)
# Out:
# Rolex
# Omega
# Tag Heuer
# Breitling
# Cartier
# Jaeger-LeCoultre
# Seiko
# Citizen
# Tissot
# Hamilton
# Longines
# Oris
# Bell & Ross
# Breguet
# Audemars Piguet
# Vacheron Constantin
# Panerai
# Tudor
# IWC
# Montblanc
# Blancpain
# Zenith
# Piaget
# Ulysse Nardin
# Jaquet Droz
# Bulgari
# Chopard
# Girard-Perregaux
# Glashütte Original
# Hublot
# Patek Philippe
# Bulova
# Sinn
# A. Lange & Sohne
# Rado
# Frederique Constant
# TAG Heuer
# Baume & Mercier
# A. Lange & Söhne

# %%
brn=input("Enter the Brand Name:")
wr=float(input("Enter the Water Resistance level in meters:"))
hr=float(input("Enter the Power Reserve in hours:"))
lbbrn=lb.fit_transform([brn])
import numpy as np
sample = np.array([[lbbrn[0], wr, hr]])
res = grid_search.best_estimator_.predict(sample)
print(res)
# Out:
# Enter the Brand Name: Rolex
# Enter the Water Resistance level in meters: 100
# Enter the Power Reserve in hours: 48
# [9150.]
# C:\Users\kahit\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
